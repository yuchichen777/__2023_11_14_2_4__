# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.167376  2.410933
# 1    a  two -0.950289 -0.383370
# 2    b  one -0.392235  0.221736
# 3    b  two -0.408915  0.124272
# 4    a  one -0.215471 -0.363663

# %%
df1 = df.set_index(keys=['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one  -0.167376  2.410933
#      two  -0.950289 -0.383370
# b    one  -0.392235  0.221736
#      two  -0.408915  0.124272
# a    one  -0.215471 -0.363663

# %%
df1.columns.name = 'data'
df1
# Out:
# data          data1     data2
# key1 key2
# a    one  -0.167376  2.410933
#      two  -0.950289 -0.383370
# b    one  -0.392235  0.221736
#      two  -0.408915  0.124272
# a    one  -0.215471 -0.363663

# %%
df2 = df1.groupby(level=['key1','key2']).mean()
df2
# Out:
# data          data1     data2
# key1 key2
# a    one  -0.191423  1.023635
#      two  -0.950289 -0.383370
# b    one  -0.392235  0.221736
#      two  -0.408915  0.124272

# %%
df2.unstack(level='key1')
# Out:
# data     data1               data2
# key1         a         b         a         b
# key2
# one  -0.191423 -0.392235  1.023635  0.221736
# two  -0.950289 -0.408915 -0.383370  0.124272
