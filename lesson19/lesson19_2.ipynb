# %%
import numpy as np
import pandas as pd
scores = np.random.randint(50,101,size=(50,5))
scores_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index = range(1,51)
             )
scores_pd
# Out:
#      國文   英文   數學  地理   歷史
# 1    66   82   69  88   54
# 2    75   90   79  73   78
# 3    50   78   86  65   57
# 4    81   70   92  67   59
# 5    55   63   58  66   55
# 6    85   89   92  85   87
# 7    90   70   99  65   55
# 8    89   76   90  98   91
# 9    92   94   64  56   73
# 10   81   99   80  78   73
# 11   82   66   83  64   87
# 12   74  100   89  63   72
# 13  100   92   61  83   51
# 14   64   55   83  92   98
# 15   85   84   78  99   73
# 16   82   88   70  62   96
# 17   62   86   87  80   82
# 18   67   68   89  92   59
# 19   70   64   71  94   53
# 20   78   71   69  91   66
# 21   94   61   82  79   86
# 22   53   96   91  78   70
# 23   62   59   95  57   87
# 24   83  100   92  71  100
# 25   71   57   80  64   86
# 26   67   68   74  72   62
# 27   68   83   74  78   66
# 28   78   98   92  57   94
# 29   74   50   78  89   93
# 30   83   79   60  64   56
# 31   90   92   76  96   84
# 32   81   73   92  99   92
# 33   99   59   55  78   55
# 34   95   56  100  77   62
# 35   66   99   65  53   90
# 36   91   58   55  85   79
# 37   92   80   99  54   84
# 38   89   92   79  65   62
# 39   70   73   92  73   94
# 40   59   73   68  72   80
# 41   91   51   84  94  100
# 42   98   71   57  75   60
# 43   58   60   88  71   95
# 44   89   93   75  92  100
# 45   93   77   75  56   75
# 46   86   93   50  72   93
# 47   73   93   75  56   83
# 48   59   99   55  92   91
# 49   50   70   57  90  100
# 50   85   86   68  98   50

# %%
def callback1(value:pd.Series):
    return pd.Series([value.max(),value.min(),value.median(),value.mean()],index=['最高分','最低分','中間值','平均值'])
    
dataFrame1 = scores_pd.apply(callback1)
dataFrame1
# Out:
#         國文      英文      數學     地理      歷史
# 最高分  100.0  100.00  100.00  99.00  100.00
# 最低分   50.0   50.00   50.00  53.00   50.00
# 中間值   81.0   77.50   78.50  76.00   79.50
# 平均值   77.5   77.68   77.44  76.36   76.96
