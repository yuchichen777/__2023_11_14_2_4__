# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
x = [0,1,2]
y = [3,4,5]
axes.plot(x,y,'bo--')
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1,3,1)
axes1.set_title("title1")
axes2 = figure.add_subplot(1,3,2)
axes2.set_title("title 2")
axes3 = figure.add_subplot(1,3,3)
axes3.set_title("title 3")

plt.show()

# %%
figure1 = plt.figure()
axes1 = figure1.add_subplot(1,1,1)
x = [0,1,2]
y = [3,4,5]
axes1.plot(x,y)

figure2 = plt.figure()
axes2 = figure2.add_subplot(1,1,1)
x1 = [2,3,6]
y1 = [2,1,2]
axes2.plot(x1,y1)

plt.show()

# %%
figure1 = plt.figure()
axes1 = figure1.add_subplot(1,1,1)
x = [0,1,2]
y = [3,4,5]

x1 = [2,3,6]
y1 = [2,1,2]

#axes1.plot(x,y,'ko-')
#axes1.plot(x1,y1,'rD--')
axes1.plot(x,y,'ko-',x1,y1,'rD--')


plt.show()

# %%
import pandas as pd

scores = [
    {'chinese':78,'english':80,'math':92,'history':75,'discover':85},
    {'chinese':92,'english':60,'math':85,'history':62,'discover':73}
]
dataFrame = pd.DataFrame(index=["robert","jenny"],data=scores)
display(dataFrame)
# Out:
#         chinese  english  math  history  discover
# robert       78       80    92       75        85
# jenny        92       60    85       62        73

# %%
subjects = list(dataFrame.columns)
subjects
# Out:
# ['chinese', 'english', 'math', 'history', 'discover']

# %%
dataFrame['chinese']
# Out:
# robert    78
# jenny     92
# Name: chinese, dtype: int64

# %%
#T,index和columns對調
swapDataFrame = dataFrame.T
display(swapDataFrame)
robert_series = swapDataFrame['robert']
display(robert_series)
jenny_series = swapDataFrame['jenny']
jenny_series
# Out:
#           robert  jenny
# chinese       78     92
# english       80     60
# math          92     85
# history       75     62
# discover      85     73
# chinese     78
# english     80
# math        92
# history     75
# discover    85
# Name: robert, dtype: int64
# chinese     92
# english     60
# math        85
# history     62
# discover    73
# Name: jenny, dtype: int64

# %%
robert_scores = robert_series.to_list()
jenny_scores = jenny_series.to_list()
display(dataFrame)
display(subjects)
display(robert_scores)
display(jenny_scores)
# Out:
#         chinese  english  math  history  discover
# robert       78       80    92       75        85
# jenny        92       60    85       62        73
# ['chinese', 'english', 'math', 'history', 'discover']
# [78, 80, 92, 75, 85]
# [92, 60, 85, 62, 73]

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#windos
font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
figure = plt.figure()
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,robert_scores,'bo-',label='徐國堂')
axes.plot(subjects,jenny_scores,'ro-',label="徐家家")
axes.legend(prop=font)
plt.show()
