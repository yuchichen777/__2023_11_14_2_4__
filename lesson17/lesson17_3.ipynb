# %%
import pandas as pd
#選取需要的欄和列
dataFrame1 = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame1.columns = ['統計年','區域別','年底人口數','土地面積','人口密度']
dataFrame2 = dataFrame1.drop(index=0)
dataFrame3 = dataFrame2.reindex(index=range(1,371))
dataFrame3
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
#value的檢查,有沒有空的欄位,資料類型
dataFrame3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    object
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
def toInt(value:str) -> int:
    try:
        newValue = int(value)
    except:
        newValue = 0
    return newValue

dataFrame3['年底人口數'] = dataFrame3['年底人口數'].map(toInt)
#dataFrame3.info()
dataFrame3
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島       0     2.38     …
# 370  106    南沙群島       0   0.5045     …
#
# [370 rows x 5 columns]

# %%
def toInt(value:str) -> int:
    try:
        newValue = int(value)
    except:
        newValue = 0
    return newValue

def toFloat(value:str) -> float:
    try:
        newValue = float(value)
    except:
        newValue = 0.0
    return newValue

dataFrame3['年底人口數'] = dataFrame3['年底人口數'].map(toInt)
dataFrame3['人口密度'] = dataFrame3['人口密度'].map(toInt)
dataFrame3['土地面積'] = dataFrame3['土地面積'].map(toFloat)
dataFrame3.info()
dataFrame3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    float64
#  4   人口密度    370 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 14.6+ KB
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484  16.3170  23747
# 3    106  新北市中和區  413590  20.1440  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360   9.9000    238
# 367  106  連江縣莒光鄉    1624   4.7000    346
# 368  106  連江縣東引鄉    1352   3.8000    356
# 369  106    東沙群島       0   2.3800      0
# 370  106    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
#subscript[slice]
dataFrame4 = dataFrame3.iloc[:5]
#使用比較運算子
dataFrame4['年底人口數'] > 400000
#使用subscript[[bool]]
dataFrame4[dataFrame4['年底人口數'] > 400000]
# Out:
#    統計年     區域別   年底人口數     土地面積   人口密度
# 1  106  新北市板橋區  551480  23.1373  23835
# 3  106  新北市中和區  413590  20.1440  20532
# 5  106  新北市新莊區  416524  19.7383  21102

# %%
#年底人口數 > 200000
dataFrame3[dataFrame3['年底人口數'] > 200000]
# Out:
#      統計年     區域別   年底人口數      土地面積   人口密度
# 1    106  新北市板橋區  551480   23.1373  23835
# 2    106  新北市三重區  387484   16.3170  23747
# 3    106  新北市中和區  413590   20.1440  20532
# 4    106  新北市永和區  222585    5.7138  38956
# 5    106  新北市新莊區  416524   19.7383  21102
# 6    106  新北市新店區  302089  120.2255   2513
# 13   106  新北市土城區  238067   29.5578   8054
# 14   106  新北市蘆洲區  201309    7.4351  27075
# 30   106  臺北市松山區  206988    9.2878  22286
# 31   106  臺北市信義區  225753   11.2077  20143
# 32   106  臺北市大安區  309969   11.3614  27283
# 33   106  臺北市中山區  230710   13.6821  16862
# 37   106  臺北市文山區  274424   31.5090   8709
# 39   106  臺北市內湖區  287771   31.5787   9113
# 40   106  臺北市士林區  288295   62.3682   4622
# 41   106  臺北市北投區  256456   56.8216   4513
# 42   106  桃園市桃園區  440840   34.8046  12666
# 43   106  桃園市中壢區  405216   76.5200   5296
# 51   106  桃園市平鎮區  224219   47.7532   4695
# 60   106  臺中市西屯區  227043   39.8467   5698
# 62   106  臺中市北屯區  274819   62.7034   4383
# ...

# %%
#土地面積 > 30
dataFrame3[dataFrame3['土地面積'] > 300]
# Out:
#      統計年      區域別  年底人口數       土地面積  人口密度
# 29   106   新北市烏來區   6320   321.1306    20
# 54   106   桃園市復興區  11505   350.7775    33
# 83   106   臺中市和平區  10949  1037.8192    11
# 157  106   高雄市桃源區   4246   928.9800     5
# 169  106   宜蘭縣大同鄉   6102   657.5442     9
# 170  106   宜蘭縣南澳鄉   5900   740.6520     8
# 182  106   新竹縣尖石鄉   9543   527.5795    18
# 201  106   苗栗縣泰安鄉   5883   614.5127    10
# 239  106   南投縣信義鄉  16253  1422.4188    11
# 240  106   南投縣仁愛鄉  15748  1273.5312    12
# 278  106  嘉義縣阿里山鄉   5631   427.8471    13
# 310  106   屏東縣獅子鄉   4806   301.0018    16
# 315  106   臺東縣卑南鄉  17399   412.6871    42
# 323  106   臺東縣延平鄉   3551   455.8805     8
# 324  106   臺東縣海端鄉   4222   880.0382     5
# 325  106   臺東縣達仁鄉   3518   306.4454    11
# 326  106   臺東縣金峰鄉   3653   380.6635    10
# 338  106   花蓮縣秀林鄉  15889  1641.8555    10
# 339  106   花蓮縣萬榮鄉   6384   618.4910    10
# 340  106   花蓮縣卓溪鄉   6066  1021.3130     6

# %%
maxValue = dataFrame3['年底人口數'].max()
dataFrame3[dataFrame3['年底人口數'] == maxValue]
# Out:
#    統計年     區域別   年底人口數     土地面積   人口密度
# 1  106  新北市板橋區  551480  23.1373  23835

# %%
minValue = dataFrame3['年底人口數'].min()
dataFrame3[dataFrame3['年底人口數'] == minValue]
# Out:
#      統計年   區域別  年底人口數    土地面積  人口密度
# 369  106  東沙群島      0  2.3800     0
# 370  106  南沙群島      0  0.5045     0

# %%
meanValue = dataFrame3['年底人口數'].mean()
dataFrame3[dataFrame3['年底人口數'] > meanValue]
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484  16.3170  23747
# 3    106  新北市中和區  413590  20.1440  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 354  106   新竹市東區  212553  33.5768   6330
# 355  106   新竹市北區  150636  15.7267   9578
# 356  106  新竹市香山區   77943  54.8491   1421
# 357  106   嘉義市東區  122103  30.1556   4049
# 358  106   嘉義市西區  147295  29.8700   4931
#
# [108 rows x 5 columns]

# %%
def getCity(value:str) -> str:
    if len(value) > 4:
        return value[:3]
    else:
        return value
    
dataFrame3['縣市'] = dataFrame3['區域別'].map(getCity)
dataFrame3
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度    縣市
# 1    106  新北市板橋區  551480  23.1373  23835   新北市
# 2    106  新北市三重區  387484  16.3170  23747   新北市
# 3    106  新北市中和區  413590  20.1440  20532   新北市
# 4    106  新北市永和區  222585   5.7138  38956   新北市
# 5    106  新北市新莊區  416524  19.7383  21102   新北市
# ..   ...     ...     ...      ...    ...   ...
# 366  106  連江縣北竿鄉    2360   9.9000    238   連江縣
# 367  106  連江縣莒光鄉    1624   4.7000    346   連江縣
# 368  106  連江縣東引鄉    1352   3.8000    356   連江縣
# 369  106    東沙群島       0   2.3800      0  東沙群島
# 370  106    南沙群島       0   0.5045      0  南沙群島
#
# [370 rows x 6 columns]
