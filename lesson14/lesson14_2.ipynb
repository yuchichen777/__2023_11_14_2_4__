# %%
#下載文字檔
import requests
url:str = 'https://data.moenv.gov.tw/api/v2/stat_p_90?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate desc&format=CSV'
response:requests.Response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
    data:str= response.text
elif response.status_code >= 400:
    print("下載失敗")    
elif response.status_code > 200:
    print("下載有問題")
# Out:
# 下載成功

# %%
with open("列管公廁.csv",mode='w',encoding='utf8') as file:
    file.write(data)

# %%
#讀取csv檔,成為python的2維資料
import csv
with open("列管公廁.csv",mode='r',encoding='utf8',newline='') as file:
    dict_reader = csv.DictReader(file)
    csv_data:list[dict] = list(dict_reader)

csv_data

# %%
#使用DataFrame顯示資料
import pandas as pd
dataFrame = pd.DataFrame(csv_data)
dataFrame
# Out:
#         itemname category year itemunit itemvalue
# 0    列管公廁個數/不分男女      連江縣  111        個       237
# 1    列管公廁個數/不分男女      金門縣  111        個       673
# 2    列管公廁個數/不分男女      嘉義市  111        個       267
# 3    列管公廁個數/不分男女      新竹市  111        個       316
# 4    列管公廁個數/不分男女      基隆市  111        個       481
# ..           ...      ...  ...      ...       ...
# 455    列管公廁個數/總計      臺中市  107        個     25536
# 456    列管公廁個數/總計      桃園市  107        個     15013
# 457    列管公廁個數/總計      臺北市  107        個     30153
# 458    列管公廁個數/總計      新北市  107        個     24478
# 459    列管公廁個數/總計       總計  107        個    197900
#
# [460 rows x 5 columns]
